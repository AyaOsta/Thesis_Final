# %%
from transformers import WhisperProcessor, WhisperForConditionalGeneration
from datasets import load_dataset

# %%
import pandas as pd
from datasets import Dataset, DatasetDict
import torchaudio

# Load Excel file
data = pd.read_excel('Aya_data.xlsx')
data['Transcription'] = data['Transcription'].str.strip()
data = data.dropna(subset=['Transcription'])
data = data.iloc[:, :3]
data['Transcription'] = data['Transcription'].str.replace('ث', 'س')
data = data.head(1850)

# Assuming your columns are 'Segment' and 'Transcription'
# data['path'] = 'Resampled_audio/' + data['Segment'] + '.wav'
data['audio'] = 'Resampled_audio/' + data['Segment'] + '.wav'

def load_audio(file_path):
    waveform, sample_rate = torchaudio.load(file_path)
    return {
        'path': file_path,
        'array': waveform.squeeze().numpy(),
        'sampling_rate': sample_rate
    }

# Apply the load_audio function to each audio file in your dataset
data['audio'] = data['audio'].apply(load_audio)

# Rename columns to match the required format
data = data.rename(columns={'Transcription': 'sentence'})
data = data.drop(columns=['Segment','ID'])

# Convert to datasets format
dataset = Dataset.from_pandas(data)

# Split the dataset into train and test
dataset = dataset.train_test_split(test_size=0.1)

# Add the dataset to DatasetDict
dataset_dict = DatasetDict({
    'train': dataset['train'],
    'test': dataset['test']
})

# Verify the format
print(dataset_dict)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['sentence', 'audio', '__index_level_0__'],
#         num_rows: 1662
#     })
#     test: Dataset({
#         features: ['sentence', 'audio', '__index_level_0__'],
#         num_rows: 185
#     })
# })

# %%
from transformers import WhisperFeatureExtractor

feature_extractor = WhisperFeatureExtractor.from_pretrained("openai/whisper-small")

# %%
from transformers import WhisperTokenizer

tokenizer = WhisperTokenizer.from_pretrained("openai/whisper-small", language="arabic", task="transcribe")
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
input_str = dataset_dict["train"][0]["sentence"]
labels = tokenizer(input_str).input_ids
decoded_with_special = tokenizer.decode(labels, skip_special_tokens=False)
decoded_str = tokenizer.decode(labels, skip_special_tokens=True)

print(f"Input:                 {input_str}")
print(f"Decoded w/ special:    {decoded_with_special}")
print(f"Decoded w/out special: {decoded_str}")
print(f"Are equal:             {input_str == decoded_str}")
# Out:
# Input:                 لأنو أنقذ الحي هيدا الولد لما الحي عرف يحبو
# Decoded w/ special:    <|startoftranscript|><|ar|><|transcribe|><|notimestamps|>لأنو أنقذ الحي هيدا الولد لما الحي عرف يحبو<|endoftext|>
# Decoded w/out special: لأنو أنقذ الحي هيدا الولد لما الحي عرف يحبو
# Are equal:             True

# %%
from transformers import WhisperProcessor

processor = WhisperProcessor.from_pretrained("openai/whisper-small", language="arabic", task="transcribe")
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
dataset_dict["train"][0]
# Out:
# {'sentence': 'لأنو أنقذ الحي هيدا الولد لما الحي عرف يحبو',
#  'audio': {'array': [0.0008544921875,
#    0.00103759765625,
#    0.00067138671875,
#    0.002288818359375,
#    0.00286865234375,
#    0.0028076171875,
#    0.002960205078125,
#    0.001739501953125,
#    0.000274658203125,
#    -3.0517578125e-05,
#    0.0,
#    -0.00079345703125,
#    -0.00128173828125,
#    -0.000579833984375,
#    0.00030517578125,
#    0.000885009765625,
#    0.000274658203125,
#    0.000457763671875,
#    0.00091552734375,
#    0.0,
#    -0.001129150390625,
#    -0.0009765625,
#    -0.000457763671875,
#    -0.000335693359375,
#    -0.000213623046875,
#    -0.000396728515625,
#    -0.0003662109375,
#    -0.000762939453125,
#    -0.0015869140625,
#    -0.00213623046875,
#    -0.001007080078125,
#    0.000518798828125,
#    0.0009765625,
#    0.00189208984375,
#    0.0032958984375,
#    0.00341796875,
#    0.00225830078125,
#    0.000885009765625,
#    -0.00091552734375,
#    -0.00140380859375,
#    -0.00103759765625,
#    -0.000732421875,
#    0.0003662109375,
#    0.000457763671875,
#    -6.103515625e-05,
#    -0.000152587890625,
#    -0.000457763671875,
#    -0.0008544921875,
#    -0.00048828125,
#    0.0,
#    0.00091552734375,
#    0.002197265625,
#    0.00128173828125,
#    6.103515625e-05,
#    0.00079345703125,
#    0.001068115234375,
#    0.0008544921875,
#    -0.0001220703125,
#    -0.0010986328125,
#    -6.103515625e-05,
#    0.00115966796875,
#    0.001495361328125,
#    0.001861572265625,
#    0.002197265625,
#    0.0010986328125,
#    -0.000274658203125,
#    -0.000823974609375,
#    -0.00091552734375,
#    -0.00042724609375,
#    0.0008544921875,
#    0.001129150390625,
#    0.00067138671875,
#    3.0517578125e-05,
#    -0.001312255859375,
#    -0.002197265625,
#    -0.002838134765625,
#    -0.002227783203125,
#    -0.001983642578125,
#    -0.001495361328125,
#    -0.000885009765625,
#    -0.0008544921875,
#    -0.000457763671875,
#    -0.00054931640625,
#    -0.000396728515625,
#    -0.00152587890625,
#    -0.002716064453125,
#    -0.002410888671875,
#    -0.00225830078125,
#    -0.002044677734375,
#    -0.001312255859375,
#    -0.00042724609375,
#    0.000213623046875,
#    0.0009765625,
#    0.001373291015625,
#    0.000396728515625,
#    -9.1552734375e-05,
#    -0.000152587890625,
#    -0.000396728515625,
#    -0.000640869140625,
#    -0.000732421875,
#    -0.000152587890625,
#    0.00054931640625,
#    0.000701904296875,
#    0.000244140625,
#    -0.000640869140625,
#    -0.002471923828125,
#    -0.00299072265625,
#    -0.002044677734375,
#    -0.000823974609375,
#    -9.1552734375e-05,
#    0.000396728515625,
#    -0.0003662109375,
#    -0.001678466796875,
#    -0.00189208984375,
#    -0.002349853515625,
#    -0.001617431640625,
#    6.103515625e-05,
#    0.00164794921875,
#    0.0010986328125,
#    0.000213623046875,
#    -0.00030517578125,
#    -0.001007080078125,
#    -0.000885009765625,
#    -0.001007080078125,
#    -0.00030517578125,
#    0.000885009765625,
#    0.000946044921875,
#    0.00030517578125,
#    0.0,
#    0.000457763671875,
#    0.000518798828125,
#    0.000885009765625,
#    0.0008544921875,
#    0.000701904296875,
#    0.001678466796875,
#    0.001708984375,
#    0.000823974609375,
#    0.00042724609375,
#    0.00079345703125,
#    0.000579833984375,
#    0.000396728515625,
#    0.001190185546875,
#    0.002532958984375,
#    0.002197265625,
#    0.001922607421875,
#    0.000885009765625,
#    0.000396728515625,
#    0.00115966796875,
#    0.000732421875,
#    0.000579833984375,
#    0.00079345703125,
#    0.0015869140625,
#    0.001312255859375,
#    0.001190185546875,
#    0.000762939453125,
#    -0.00018310546875,
#    -0.00030517578125,
#    -0.000396728515625,
#    -0.000762939453125,
#    -6.103515625e-05,
#    0.00048828125,
#    0.000640869140625,
#    0.00103759765625,
#    0.00091552734375,
#    9.1552734375e-05,
#    -0.000701904296875,
#    -0.00042724609375,
#    -0.000579833984375,
#    -0.0001220703125,
#    0.001068115234375,
#    0.00128173828125,
#    -3.0517578125e-05,
#    -0.000335693359375,
#    -0.0001220703125,
#    -0.000762939453125,
#    -0.000244140625,
#    -9.1552734375e-05,
#    0.0001220703125,
#    0.000396728515625,
#    0.000579833984375,
#    0.0003662109375,
#    -9.1552734375e-05,
#    -0.0001220703125,
#    -0.0006103515625,
#    -0.000732421875,
#    -0.001739501953125,
#    -0.002197265625,
#    -0.001556396484375,
#    -0.001129150390625,
#    -0.0009765625,
#    -0.000457763671875,
#    -0.000152587890625,
#    -3.0517578125e-05,
#    -0.00048828125,
#    -0.0010986328125,
#    -0.000885009765625,
#    -0.0001220703125,
#    0.000396728515625,
#    0.000244140625,
#    0.00054931640625,
#    0.00079345703125,
#    0.001617431640625,
#    0.001495361328125,
#    0.001495361328125,
#    0.002105712890625,
#    0.00189208984375,
#    0.00152587890625,
#    0.001708984375,
#    0.002532958984375,
#    0.002105712890625,
#    0.001495361328125,
#    0.000732421875,
#    -0.000640869140625,
#    -0.002349853515625,
#    -0.002777099609375,
#    -0.00225830078125,
#    -0.001800537109375,
#    -0.000640869140625,
#    -0.000579833984375,
#    -0.000579833984375,
#    -0.000579833984375,
#    -0.001068115234375,
#    -0.00115966796875,
#    -0.001251220703125,
#    -0.001434326171875,
#    -0.00115966796875,
#    -0.00030517578125,
#    0.000152587890625,
#    0.0006103515625,
#    0.000885009765625,
#    -3.0517578125e-05,
#    -0.001129150390625,
#    -0.00146484375,
#    -0.0013427734375,
#    -0.00018310546875,
#    0.000732421875,
#    0.001800537109375,
#    0.002197265625,
#    0.001556396484375,
#    0.0003662109375,
#    -0.001220703125,
#    -0.002227783203125,
#    -0.002532958984375,
#    -0.001556396484375,
#    -0.0009765625,
#    0.0001220703125,
#    0.001312255859375,
#    0.000946044921875,
#    -6.103515625e-05,
#    -0.000885009765625,
#    -0.001190185546875,
#    -0.001678466796875,
#    -0.001373291015625,
#    -0.00030517578125,
#    0.000640869140625,
#    0.001495361328125,
#    0.00189208984375,
#    0.00079345703125,
#    -0.00030517578125,
#    -0.000732421875,
#    -0.000823974609375,
#    -9.1552734375e-05,
#    0.000457763671875,
#    0.001495361328125,
#    0.0015869140625,
#    0.0008544921875,
#    -0.000213623046875,
#    -0.00152587890625,
#    -0.002166748046875,
#    -0.0018310546875,
#    -0.0015869140625,
#    -0.00091552734375,
#    -9.1552734375e-05,
#    -0.000244140625,
#    -0.000335693359375,
#    -0.0009765625,
#    -0.001983642578125,
#    -0.002532958984375,
#    -0.001617431640625,
#    -0.001220703125,
#    3.0517578125e-05,
#    0.001739501953125,
#    0.0018310546875,
#    0.001556396484375,
#    0.000244140625,
#    -0.00042724609375,
#    -0.00079345703125,
#    -0.00079345703125,
#    -0.000335693359375,
#    0.00067138671875,
#    0.00177001953125,
#    0.001983642578125,
#    0.001983642578125,
#    0.001373291015625,
#    0.001708984375,
#    0.0010986328125,
#    -0.00048828125,
#    -0.0006103515625,
#    -0.000274658203125,
#    0.000244140625,
#    0.00048828125,
#    0.000457763671875,
#    0.0,
#    -0.00030517578125,
#    -0.00048828125,
#    -0.000885009765625,
#    -0.000640869140625,
#    6.103515625e-05,
#    0.00018310546875,
#    0.0001220703125,
#    0.0001220703125,
#    -0.000244140625,
#    -0.00048828125,
#    -0.00079345703125,
#    -0.0001220703125,
#    0.00067138671875,
#    0.001190185546875,
#    0.001129150390625,
#    0.001068115234375,
#    0.0010986328125,
#    0.00042724609375,
#    -3.0517578125e-05,
#    -0.0001220703125,
#    0.000274658203125,
#    0.0006103515625,
#    0.0015869140625,
#    0.002105712890625,
#    0.002227783203125,
#    0.0018310546875,
#    0.000701904296875,
#    -0.000335693359375,
#    -0.000946044921875,
#    -0.000457763671875,
#    6.103515625e-05,
#    0.000762939453125,
#    0.001312255859375,
#    0.00115966796875,
#    0.000152587890625,
#    -0.0010986328125,
#    -0.001373291015625,
#    -0.001068115234375,
#    -0.00091552734375,
#    -0.000335693359375,
#    0.000396728515625,
#    0.001251220703125,
#    0.00146484375,
#    0.001007080078125,
#    3.0517578125e-05,
#    -0.001190185546875,
#    -0.001556396484375,
#    -0.001556396484375,
#    -0.000946044921875,
#    6.103515625e-05,
#    0.00091552734375,
#    0.000946044921875,
#    0.000396728515625,
#    0.00030517578125,
#    0.0001220703125,
#    -9.1552734375e-05,
#    0.00018310546875,
#    0.000579833984375,
#    0.000762939453125,
#    0.001068115234375,
#    0.001251220703125,
#    0.000579833984375,
#    0.000244140625,
#    0.00054931640625,
#    0.0003662109375,
#    3.0517578125e-05,
#    0.000213623046875,
#    0.00042724609375,
#    0.00054931640625,
#    0.0009765625,
#    0.000518798828125,
#    -0.000213623046875,
#    -0.000335693359375,
#    -0.0006103515625,
#    -0.000579833984375,
#    -0.000335693359375,
#    0.000396728515625,
#    0.00079345703125,
#    0.0009765625,
#    0.000885009765625,
#    0.000518798828125,
#    0.00042724609375,
#    -0.000244140625,
#    -0.000335693359375,
#    -9.1552734375e-05,
#    0.000396728515625,
#    0.00091552734375,
#    0.00091552734375,
#    0.00079345703125,
#    0.000701904296875,
#    -6.103515625e-05,
#    -0.00042724609375,
#    -0.000762939453125,
#    -0.00115966796875,
#    -0.000762939453125,
#    -0.0006103515625,
#    -0.00054931640625,
#    -0.000640869140625,
#    -0.000518798828125,
#    -0.000823974609375,
#    -0.0013427734375,
#    -0.001190185546875,
#    -0.0006103515625,
#    -3.0517578125e-05,
#    3.0517578125e-05,
#    6.103515625e-05,
#    -0.000152587890625,
#    -3.0517578125e-05,
#    0.000823974609375,
#    0.000244140625,
#    -0.0006103515625,
#    3.0517578125e-05,
#    0.000457763671875,
#    0.000762939453125,
#    0.001068115234375,
#    0.000457763671875,
#    -9.1552734375e-05,
#    -0.000152587890625,
#    -0.000213623046875,
#    -0.000152587890625,
#    0.000152587890625,
#    -6.103515625e-05,
#    0.000274658203125,
#    0.00048828125,
#    0.0001220703125,
#    -3.0517578125e-05,
#    -0.00067138671875,
#    -0.0009765625,
#    -0.00115966796875,
#    -0.000885009765625,
#    -0.0001220703125,
#    -0.0001220703125,
#    -0.000732421875,
#    -0.000396728515625,
#    -0.00030517578125,
#    -0.001007080078125,
#    -0.00079345703125,
#    -0.001495361328125,
#    -0.0010986328125,
#    0.00042724609375,
#    0.000457763671875,
#    0.000762939453125,
#    0.00103759765625,
#    0.000640869140625,
#    -3.0517578125e-05,
#    -0.000335693359375,
#    -0.00042724609375,
#    -0.0010986328125,
#    -0.0013427734375,
#    -0.0006103515625,
#    -0.000274658203125,
#    0.00164794921875,
#    0.00115966796875,
#    0.00067138671875,
#    -0.001373291015625,
#    0.000396728515625,
#    -0.008575439453125,
#    -0.01837158203125,
#    0.002838134765625,
#    0.0057373046875,
#    0.004302978515625,
#    0.010406494140625,
#    0.001983642578125,
#    0.001434326171875,
#    -0.002288818359375,
#    -0.01080322265625,
#    -0.011199951171875,
#    -0.001312255859375,
#    0.000762939453125,
#    -0.003143310546875,
#    0.006439208984375,
#    0.0113525390625,
#    0.0054931640625,
#    0.0001220703125,
#    -0.003814697265625,
#    -0.005340576171875,
#    -0.00628662109375,
#    -0.004119873046875,
#    -0.0008544921875,
#    0.00360107421875,
#    0.00732421875,
#    -0.004669189453125,
#    -0.0108642578125,
#    0.0042724609375,
#    0.006591796875,
#    -0.0009765625,
#    0.001922607421875,
#    0.001739501953125,
#    0.00091552734375,
#    0.00048828125,
#    -0.00567626953125,
#    -0.0042724609375,
#    0.0018310546875,
#    0.000518798828125,
#    -0.003387451171875,
#    0.002166748046875,
#    0.00909423828125,
#    0.00390625,
#    -0.000823974609375,
#    -0.000579833984375,
#    -0.00286865234375,
#    -0.0062255859375,
#    -0.00494384765625,
#    -0.0009765625,
#    0.002960205078125,
#    0.005859375,
#    0.004302978515625,
#    0.00189208984375,
#    0.0009765625,
#    -0.003021240234375,
#    -0.006683349609375,
#    -0.003753662109375,
#    0.000701904296875,
#    0.002777099609375,
#    0.003265380859375,
#    0.00390625,
#    0.00347900390625,
#    0.000396728515625,
#    -0.002593994140625,
#    -0.00299072265625,
#    -0.002532958984375,
#    -0.001708984375,
#    0.000335693359375,
#    0.00286865234375,
#    0.005462646484375,
#    0.0042724609375,
#    0.000518798828125,
#    -0.0009765625,
#    -0.001678466796875,
#    -0.002166748046875,
#    -0.0010986328125,
#    0.001129150390625,
#    0.0023193359375,
#    0.00238037109375,
#    0.00164794921875,
#    0.0006103515625,
#    -9.1552734375e-05,
#    -0.001129150390625,
#    -0.001312255859375,
#    -0.000457763671875,
#    0.000823974609375,
#    0.00140380859375,
#    0.001251220703125,
#    0.000946044921875,
#    0.000823974609375,
#    -0.000335693359375,
#    -0.0010986328125,
#    -0.000732421875,
#    -0.000213623046875,
#    0.00030517578125,
#    0.00054931640625,
#    0.001312255859375,
#    0.0009765625,
#    0.0001220703125,
#    -0.000762939453125,
#    -0.001190185546875,
#    -0.00103759765625,
#    -0.000701904296875,
#    -0.0006103515625,
#    -0.000457763671875,
#    0.000244140625,
#    6.103515625e-05,
#    -0.000579833984375,
#    -0.0006103515625,
#    -0.00079345703125,
#    -0.001220703125,
#    -0.00103759765625,
#    -0.000579833984375,
#    6.103515625e-05,
#    0.000396728515625,
#    0.0,
#    -0.000518798828125,
#    -0.000823974609375,
#    -0.001190185546875,
#    -0.000946044921875,
#    -0.0008544921875,
#    -0.000732421875,
#    -0.000244140625,
#    6.103515625e-05,
#    0.000640869140625,
#    0.000732421875,
#    0.00030517578125,
#    -0.000152587890625,
#    -0.00054931640625,
#    -0.000640869140625,
#    -0.0003662109375,
#    0.000335693359375,
#    0.000946044921875,
#    0.000885009765625,
#    0.00079345703125,
#    0.000762939453125,
#    0.000457763671875,
#    0.00018310546875,
#    -9.1552734375e-05,
#    0.000213623046875,
#    0.00054931640625,
#    0.000579833984375,
#    0.00091552734375,
#    0.001068115234375,
#    0.00103759765625,
#    0.00067138671875,
#    0.00054931640625,
#    -3.0517578125e-05,
#    -0.00018310546875,
#    0.000152587890625,
#    0.00018310546875,
#    0.000518798828125,
#    0.000457763671875,
#    0.000335693359375,
#    0.000244140625,
#    0.000213623046875,
#    -3.0517578125e-05,
#    -0.0001220703125,
#    9.1552734375e-05,
#    -0.000244140625,
#    -0.00018310546875,
#    3.0517578125e-05,
#    -0.000335693359375,
#    3.0517578125e-05,
#    -0.0001220703125,
#    -0.000335693359375,
#    0.000244140625,
#    0.000213623046875,
#    -3.0517578125e-05,
#    0.000244140625,
#    0.00054931640625,
#    9.1552734375e-05,
#    0.000396728515625,
#    0.000335693359375,
#    0.00048828125,
#    0.00091552734375,
#    0.000946044921875,
#    0.0008544921875,
#    0.00091552734375,
#    0.001373291015625,
#    0.00054931640625,
#    0.00067138671875,
#    0.000885009765625,
#    0.00067138671875,
#    0.000640869140625,
#    0.0006103515625,
#    0.000701904296875,
#    0.00067138671875,
#    0.000518798828125,
#    0.00018310546875,
#    0.000274658203125,
#    3.0517578125e-05,
#    0.000213623046875,
#    -3.0517578125e-05,
#    -0.000152587890625,
#    0.000213623046875,
#    0.00018310546875,
#    0.000244140625,
#    0.0006103515625,
#    0.000579833984375,
#    0.000640869140625,
#    0.000823974609375,
#    0.000457763671875,
#    0.000762939453125,
#    0.000732421875,
#    0.000335693359375,
#    0.00030517578125,
#    0.000640869140625,
#    0.00048828125,
#    0.000396728515625,
#    0.000823974609375,
#    0.00042724609375,
#    0.00048828125,
#    0.000244140625,
#    0.000213623046875,
#    0.000213623046875,
#    0.00030517578125,
#    0.00054931640625,
#    0.000274658203125,
#    0.000579833984375,
#    0.000335693359375,
#    0.0,
#    -0.000152587890625,
#    -0.00048828125,
#    -0.000274658203125,
#    -6.103515625e-05,
#    0.000213623046875,
#    0.00030517578125,
#    0.000152587890625,
#    0.000457763671875,
#    -9.1552734375e-05,
#    -0.000213623046875,
#    -0.000152587890625,
#    -0.00030517578125,
#    -3.0517578125e-05,
#    0.0,
#    0.000457763671875,
#    0.0006103515625,
#    6.103515625e-05,
#    -0.000152587890625,
#    -0.000396728515625,
#    -0.00048828125,
#    -0.000274658203125,
#    -0.000396728515625,
#    -0.000335693359375,
#    0.000274658203125,
#    0.000335693359375,
#    -6.103515625e-05,
#    0.000244140625,
#    -6.103515625e-05,
#    -0.00054931640625,
#    -0.000518798828125,
#    -0.00030517578125,
#    -9.1552734375e-05,
#    -6.103515625e-05,
#    0.000335693359375,
#    0.000518798828125,
#    0.000274658203125,
#    0.0,
#    -3.0517578125e-05,
#    -0.00018310546875,
#    -0.0003662109375,
#    -0.000244140625,
#    -0.000274658203125,
#    -0.00030517578125,
#    -0.000244140625,
#    -0.00018310546875,
#    -0.0003662109375,
#    -0.000640869140625,
#    -0.00067138671875,
#    -0.00054931640625,
#    -0.00048828125,
#    -0.000579833984375,
#    -0.000457763671875,
#    -0.000579833984375,
#    -0.000885009765625,
#    -0.001007080078125,
#    -0.00079345703125,
#    -0.000732421875,
#    -0.00079345703125,
#    -0.000732421875,
#    -0.000762939453125,
#    -0.000823974609375,
#    -0.000579833984375,
#    -0.00054931640625,
#    -0.000946044921875,
#    -0.000518798828125,
#    -0.00048828125,
#    -0.000518798828125,
#    -0.00048828125,
#    -0.000457763671875,
#    -9.1552734375e-05,
#    -9.1552734375e-05,
#    0.0,
#    -0.00018310546875,
#    -0.000823974609375,
#    -0.00201416015625,
#    -0.002655029296875,
#    -0.0023193359375,
#    -0.0023193359375,
#    -0.00274658203125,
#    -0.002655029296875,
#    -0.00250244140625,
#    -0.002471923828125,
#    -0.00250244140625,
#    -0.002532958984375,
#    -0.00274658203125,
#    -0.002685546875,
#    -0.00225830078125,
#    -0.00213623046875,
#    -0.001800537109375,
#    -0.001708984375,
#    -0.00140380859375,
#    -0.00152587890625,
#    -0.001373291015625,
#    -0.000823974609375,
#    -0.000274658203125,
#    0.000274658203125,
#    0.00030517578125,
#    0.000457763671875,
#    0.0003662109375,
#    0.0003662109375,
#    0.0006103515625,
#    0.000518798828125,
#    0.00042724609375,
#    0.0003662109375,
#    0.000274658203125,
#    0.00048828125,
#    0.00030517578125,
#    0.000396728515625,
#    0.000457763671875,
#    -0.000244140625,
#    -0.00042724609375,
#    -0.00030517578125,
#    -0.000152587890625,
#    -0.00048828125,
#    -0.000732421875,
#    -0.00079345703125,
#    -0.0009765625,
#    -0.000762939453125,
#    -0.00103759765625,
#    -0.000762939453125,
#    -0.000579833984375,
#    -0.000701904296875,
#    -0.000335693359375,
#    -0.00042724609375,
#    -0.000335693359375,
#    -3.0517578125e-05,
#    0.000152587890625,
#    3.0517578125e-05,
#    -0.000152587890625,
#    0.0001220703125,
#    0.00054931640625,
#    0.00054931640625,
#    0.000885009765625,
#    0.000946044921875,
#    0.00091552734375,
#    0.001007080078125,
#    0.0008544921875,
#    0.000946044921875,
#    0.00067138671875,
#    0.000579833984375,
#    0.00079345703125,
#    0.00091552734375,
#    0.001007080078125,
#    0.001251220703125,
#    0.00103759765625,
#    0.000885009765625,
#    0.000762939453125,
#    0.000457763671875,
#    0.00054931640625,
#    0.00048828125,
#    0.00054931640625,
#    0.00054931640625,
#    0.0003662109375,
#    0.000335693359375,
#    0.000335693359375,
#    0.00030517578125,
#    0.000457763671875,
#    0.000396728515625,
#    0.000732421875,
#    0.000762939453125,
#    0.000457763671875,
#    0.000457763671875,
#    0.000335693359375,
#    0.000457763671875,
#    0.000579833984375,
#    0.000946044921875,
#    0.00103759765625,
#    0.0009765625,
#    0.001312255859375,
#    0.001007080078125,
#    0.0008544921875,
#    0.00079345703125,
#    0.00079345703125,
#    0.00054931640625,
#    0.000579833984375,
#    0.000946044921875,
#    0.000885009765625,
#    0.001068115234375,
#    0.000885009765625,
#    0.000518798828125,
#    0.00048828125,
#    0.000579833984375,
#    0.00054931640625,
#    0.0008544921875,
#    0.000579833984375,
#    0.000244140625,
#    3.0517578125e-05,
#    6.103515625e-05,
#    3.0517578125e-05,
#    -0.000152587890625,
#    0.0001220703125,
#    0.000457763671875,
#    0.00048828125,
#    0.000396728515625,
#    0.00042724609375,
#    0.000396728515625,
#    0.0003662109375,
#    0.000274658203125,
#    0.000213623046875,
#    3.0517578125e-05,
#    0.00030517578125,
#    0.0003662109375,
#    0.000396728515625,
#    0.00048828125,
#    6.103515625e-05,
#    3.0517578125e-05,
#    0.000152587890625,
#    0.000244140625,
#    0.00042724609375,
#    0.00054931640625,
#    0.0006103515625,
#    0.00048828125,
#    0.00067138671875,
#    0.0003662109375,
#    0.00030517578125,
#    0.00018310546875,
#    6.103515625e-05,
#    0.000213623046875,
#    -0.000152587890625,
#    0.000457763671875,
#    0.000244140625,
#    0.0001220703125,
#    3.0517578125e-05,
#    -6.103515625e-05,
#    0.000213623046875,
#    3.0517578125e-05,
#    6.103515625e-05,
#    0.0,
#    9.1552734375e-05,
#    3.0517578125e-05,
#    -3.0517578125e-05,
#    -9.1552734375e-05,
#    -3.0517578125e-05,
#    0.000152587890625,
#    0.0,
#    -3.0517578125e-05,
#    0.00018310546875,
#    -0.0001220703125,
#    6.103515625e-05,
#    0.00042724609375,
#    0.000457763671875,
#    0.0003662109375,
#    0.0001220703125,
#    -6.103515625e-05,
#    -0.000244140625,
#    3.0517578125e-05,
#    -0.000152587890625,
#    -0.0001220703125,
#    0.000152587890625,
#    9.1552734375e-05,
#    0.000213623046875,
#    0.000152587890625,
#    -0.000152587890625,
#    -0.0003662109375,
#    -0.00018310546875,
#    -9.1552734375e-05,
#    -6.103515625e-05,
#    3.0517578125e-05,
#    -6.103515625e-05,
#    6.103515625e-05,
#    -0.000152587890625,
#    -0.000457763671875,
#    -0.000335693359375,
#    -0.00018310546875,
#    -0.000274658203125,
#    -0.000396728515625,
#    -0.000274658203125,
#    -0.0001220703125,
#    -0.00030517578125,
#    -0.000274658203125,
#    -6.103515625e-05,
#    -9.1552734375e-05,
#    -0.000213623046875,
#    -0.000396728515625,
#    -0.000396728515625,
#    -0.000396728515625,
#    -0.0001220703125,
#    -0.00018310546875,
#    -0.0003662109375,
#    -9.1552734375e-05,
#    -0.000335693359375,
#    -0.000457763671875,
#    -0.000396728515625,
#    -9.1552734375e-05,
#    -0.000213623046875,
#    -0.00030517578125,
#    -0.0001220703125,
#    -0.0001220703125,
#    -0.00030517578125,
#    -0.0003662109375,
#    -0.000457763671875,
#    -0.00067138671875,
#    -0.000457763671875,
#    -0.0006103515625,
#    -0.0003662109375,
#    -0.000579833984375,
#    -0.000732421875,
#    -0.000640869140625,
#    -0.00091552734375,
#    -0.000885009765625,
#    -0.0008544921875,
#    -0.000946044921875,
#    -0.001007080078125,
#    -0.0010986328125,
#    -0.000701904296875,
#    -0.000885009765625,
#    -0.001251220703125,
#    -0.00115966796875,
#    -0.001220703125,
#    -0.001007080078125,
#    -0.0009765625,
#    -0.0010986328125,
#    -0.00103759765625,
#    -0.00103759765625,
#    -0.000823974609375,
#    -0.000640869140625,
#    -0.000579833984375,
#    -0.00042724609375,
#    -0.000457763671875,
#    -0.00067138671875,
#    ...],
#   'path': 'Resampled_audio/yt15_2820_2835_1.wav',
#   'sampling_rate': 16000},
#  '__index_level_0__': 1583}

# %%
def prepare_dataset(batch):
    # load and resample audio data from 48 to 16kHz
    audio = batch["audio"]

    # compute log-Mel input features from input audio array 
    batch["input_features"] = feature_extractor(audio["array"], sampling_rate=audio["sampling_rate"]).input_features[0]

    # encode target text to label ids 
    batch["labels"] = tokenizer(batch["sentence"]).input_ids
    return batch

# %%
dataset_dict = dataset_dict.map(prepare_dataset,batch_size=4, remove_columns=dataset_dict.column_names["train"], num_proc=1)
# Out:
# Map:   0%|          | 0/1662 [00:00<?, ? examples/s]
# Map:   0%|          | 0/185 [00:00<?, ? examples/s]

# %%
from transformers import WhisperForConditionalGeneration

model = WhisperForConditionalGeneration.from_pretrained("openai/whisper-small")

# %%
model.generation_config.language = "arabic"
model.generation_config.task = "transcribe"

model.generation_config.forced_decoder_ids = None

# %%
import torch

from dataclasses import dataclass
from typing import Any, Dict, List, Union

@dataclass
class DataCollatorSpeechSeq2SeqWithPadding:
    processor: Any
    decoder_start_token_id: int

    def __call__(self, features: List[Dict[str, Union[List[int], torch.Tensor]]]) -> Dict[str, torch.Tensor]:
        # split inputs and labels since they have to be of different lengths and need different padding methods
        # first treat the audio inputs by simply returning torch tensors
        input_features = [{"input_features": feature["input_features"]} for feature in features]
        batch = self.processor.feature_extractor.pad(input_features, return_tensors="pt")

        # get the tokenized label sequences
        label_features = [{"input_ids": feature["labels"]} for feature in features]
        # pad the labels to max length
        labels_batch = self.processor.tokenizer.pad(label_features, return_tensors="pt")

        # replace padding with -100 to ignore loss correctly
        labels = labels_batch["input_ids"].masked_fill(labels_batch.attention_mask.ne(1), -100)

        # if bos token is appended in previous tokenization step,
        # cut bos token here as it's append later anyways
        if (labels[:, 0] == self.decoder_start_token_id).all().cpu().item():
            labels = labels[:, 1:]

        batch["labels"] = labels

        return batch

# %%
data_collator = DataCollatorSpeechSeq2SeqWithPadding(
    processor=processor,
    decoder_start_token_id=model.config.decoder_start_token_id,
)

# %%
import evaluate

metric = evaluate.load("wer")

# %%
def compute_metrics(pred):
    pred_ids = pred.predictions
    label_ids = pred.label_ids

    # replace -100 with the pad_token_id
    label_ids[label_ids == -100] = tokenizer.pad_token_id

    # we do not want to group tokens when computing the metrics
    pred_str = tokenizer.batch_decode(pred_ids, skip_special_tokens=True)
    label_str = tokenizer.batch_decode(label_ids, skip_special_tokens=True)

    wer = 100 * metric.compute(predictions=pred_str, references=label_str)

    return {"wer": wer}

# %%
from transformers import Seq2SeqTrainingArguments

training_args = Seq2SeqTrainingArguments(
    output_dir="./lebanese_dialect_asr",  # change to a repo name of your choice
    per_device_train_batch_size=16,
    gradient_accumulation_steps=1,  # increase by 2x for every 2x decrease in batch size
    learning_rate=1e-5,
    warmup_steps=100,
    max_steps=800,
    gradient_checkpointing=True,
    fp16=True,
    evaluation_strategy="steps",
    per_device_eval_batch_size=8,
    predict_with_generate=True,
    generation_max_length=448,
    save_steps=10,
    eval_steps=10,
    logging_steps=25,
    report_to=["tensorboard"],
    load_best_model_at_end=True,
    metric_for_best_model="wer",
    greater_is_better=False,
    push_to_hub=False,
)

# %%
from transformers import Seq2SeqTrainer

trainer = Seq2SeqTrainer(
    args=training_args,
    model=model,
    train_dataset=dataset_dict["train"],
    eval_dataset=dataset_dict["test"],
    data_collator=data_collator,
    compute_metrics=compute_metrics,
    tokenizer=processor.feature_extractor, 
)
# Out:
# max_steps is given, it will override any value given in num_train_epochs

# %%
trainer.train()
# Out:
#   0%|          | 0/600 [00:00<?, ?it/s]
#   0%|          | 0/24 [00:00<?, ?it/s]
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}
# {'eval_loss': 1.4717897176742554, 'eval_wer': 70.10078387458006, 'eval_runtime': 994.6711, 'eval_samples_per_second': 0.186, 'eval_steps_per_second': 0.024, 'epoch': 0.1}
# c:\Users\PcUser\anaconda3\Lib\site-packages\torch\utils\checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#   0%|          | 0/24 [00:00<?, ?it/s]
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}
# {'eval_loss': 1.2806240320205688, 'eval_wer': 91.0414333706607, 'eval_runtime': 1074.7082, 'eval_samples_per_second': 0.172, 'eval_steps_per_second': 0.022, 'epoch': 0.19}
# c:\Users\PcUser\anaconda3\Lib\site-packages\torch\utils\checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# {'loss': 1.3871, 'grad_norm': 21.183425903320312, 'learning_rate': 2.5e-06, 'epoch': 0.24}
#   0%|          | 0/24 [00:00<?, ?it/s]
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}
# {'eval_loss': 1.0599316358566284, 'eval_wer': 87.79395296752519, 'eval_runtime': 1145.0129, 'eval_samples_per_second': 0.162, 'eval_steps_per_second': 0.021, 'epoch': 0.29}
# c:\Users\PcUser\anaconda3\Lib\site-packages\torch\utils\checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#   0%|          | 0/24 [00:00<?, ?it/s]
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}
# {'eval_loss': 0.8353036046028137, 'eval_wer': 63.71780515117581, 'eval_runtime': 1321.4162, 'eval_samples_per_second': 0.14, 'eval_steps_per_second': 0.018, 'epoch': 0.38}
# c:\Users\PcUser\anaconda3\Lib\site-packages\torch\utils\checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# {'loss': 0.9078, 'grad_norm': 16.55497169494629, 'learning_rate': 5e-06, 'epoch': 0.48}
#   0%|          | 0/24 [00:00<?, ?it/s]
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}
# {'eval_loss': 0.7290633320808411, 'eval_wer': 59.12653975363942, 'eval_runtime': 1072.804, 'eval_samples_per_second': 0.172, 'eval_steps_per_second': 0.022, 'epoch': 0.48}
# c:\Users\PcUser\anaconda3\Lib\site-packages\torch\utils\checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#   0%|          | 0/24 [00:00<?, ?it/s]
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}
# {'eval_loss': 0.6730122566223145, 'eval_wer': 55.5431131019037, 'eval_runtime': 993.2234, 'eval_samples_per_second': 0.186, 'eval_steps_per_second': 0.024, 'epoch': 0.58}
# c:\Users\PcUser\anaconda3\Lib\site-packages\torch\utils\checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#   0%|          | 0/24 [00:00<?, ?it/s]
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}
# {'eval_loss': 0.627424955368042, 'eval_wer': 53.75139977603583, 'eval_runtime': 1006.3072, 'eval_samples_per_second': 0.184, 'eval_steps_per_second': 0.024, 'epoch': 0.67}
# c:\Users\PcUser\anaconda3\Lib\site-packages\torch\utils\checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# {'loss': 0.6324, 'grad_norm': 13.560270309448242, 'learning_rate': 7.500000000000001e-06, 'epoch': 0.72}
#   0%|          | 0/24 [00:00<?, ?it/s]
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}
# {'eval_loss': 0.6073374152183533, 'eval_wer': 53.75139977603583, 'eval_runtime': 997.9717, 'eval_samples_per_second': 0.185, 'eval_steps_per_second': 0.024, 'epoch': 0.77}
# c:\Users\PcUser\anaconda3\Lib\site-packages\torch\utils\checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#   0%|          | 0/24 [00:00<?, ?it/s]
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}
# {'eval_loss': 0.5832021832466125, 'eval_wer': 51.28779395296752, 'eval_runtime': 1082.2183, 'eval_samples_per_second': 0.171, 'eval_steps_per_second': 0.022, 'epoch': 0.87}
# c:\Users\PcUser\anaconda3\Lib\site-packages\torch\utils\checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# {'loss': 0.5906, 'grad_norm': 11.420475006103516, 'learning_rate': 1e-05, 'epoch': 0.96}
#   0%|          | 0/24 [00:00<?, ?it/s]
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}
# {'eval_loss': 0.5568668842315674, 'eval_wer': 50.72788353863382, 'eval_runtime': 1079.0583, 'eval_samples_per_second': 0.171, 'eval_steps_per_second': 0.022, 'epoch': 0.96}
# c:\Users\PcUser\anaconda3\Lib\site-packages\torch\utils\checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#   0%|          | 0/24 [00:00<?, ?it/s]
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}
# {'eval_loss': 0.5415148735046387, 'eval_wer': 49.0481522956327, 'eval_runtime': 1003.9725, 'eval_samples_per_second': 0.184, 'eval_steps_per_second': 0.024, 'epoch': 1.06}
# c:\Users\PcUser\anaconda3\Lib\site-packages\torch\utils\checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#   0%|          | 0/24 [00:00<?, ?it/s]
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}
# {'eval_loss': 0.5363702178001404, 'eval_wer': 48.488241881299, 'eval_runtime': 1004.266, 'eval_samples_per_second': 0.184, 'eval_steps_per_second': 0.024, 'epoch': 1.15}
# c:\Users\PcUser\anaconda3\Lib\site-packages\torch\utils\checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# {'loss': 0.4071, 'grad_norm': 12.28740406036377, 'learning_rate': 9.5e-06, 'epoch': 1.2}
#   0%|          | 0/24 [00:00<?, ?it/s]
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}
# {'eval_loss': 0.5202776789665222, 'eval_wer': 47.704367301231805, 'eval_runtime': 1010.5781, 'eval_samples_per_second': 0.183, 'eval_steps_per_second': 0.024, 'epoch': 1.25}
# c:\Users\PcUser\anaconda3\Lib\site-packages\torch\utils\checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#   0%|          | 0/24 [00:00<?, ?it/s]
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}
# {'eval_loss': 0.512990415096283, 'eval_wer': 46.58454647256439, 'eval_runtime': 992.8164, 'eval_samples_per_second': 0.186, 'eval_steps_per_second': 0.024, 'epoch': 1.35}
# c:\Users\PcUser\anaconda3\Lib\site-packages\torch\utils\checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# {'loss': 0.3633, 'grad_norm': 9.400293350219727, 'learning_rate': 9e-06, 'epoch': 1.44}
#   0%|          | 0/24 [00:00<?, ?it/s]
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}
# {'eval_loss': 0.5245764255523682, 'eval_wer': 47.1444568868981, 'eval_runtime': 999.6058, 'eval_samples_per_second': 0.185, 'eval_steps_per_second': 0.024, 'epoch': 1.44}
# c:\Users\PcUser\anaconda3\Lib\site-packages\torch\utils\checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#   0%|          | 0/24 [00:00<?, ?it/s]
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}
# {'eval_loss': 0.520716667175293, 'eval_wer': 47.25643896976484, 'eval_runtime': 992.4794, 'eval_samples_per_second': 0.186, 'eval_steps_per_second': 0.024, 'epoch': 1.54}
# c:\Users\PcUser\anaconda3\Lib\site-packages\torch\utils\checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#   0%|          | 0/24 [00:00<?, ?it/s]
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}
# {'eval_loss': 0.5197635293006897, 'eval_wer': 46.360582306830906, 'eval_runtime': 994.6079, 'eval_samples_per_second': 0.186, 'eval_steps_per_second': 0.024, 'epoch': 1.63}
# c:\Users\PcUser\anaconda3\Lib\site-packages\torch\utils\checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# {'loss': 0.326, 'grad_norm': 10.040719032287598, 'learning_rate': 8.5e-06, 'epoch': 1.68}
#   0%|          | 0/24 [00:00<?, ?it/s]
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}
# {'eval_loss': 0.5050758123397827, 'eval_wer': 45.24076147816349, 'eval_runtime': 1007.0071, 'eval_samples_per_second': 0.184, 'eval_steps_per_second': 0.024, 'epoch': 1.73}
# c:\Users\PcUser\anaconda3\Lib\site-packages\torch\utils\checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#   0%|          | 0/24 [00:00<?, ?it/s]
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}
# {'eval_loss': 0.49682188034057617, 'eval_wer': 45.464725643896976, 'eval_runtime': 995.5431, 'eval_samples_per_second': 0.186, 'eval_steps_per_second': 0.024, 'epoch': 1.83}
# c:\Users\PcUser\anaconda3\Lib\site-packages\torch\utils\checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# {'loss': 0.3738, 'grad_norm': 12.1381254196167, 'learning_rate': 8.000000000000001e-06, 'epoch': 1.92}
#   0%|          | 0/24 [00:00<?, ?it/s]
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}
# {'eval_loss': 0.4822646677494049, 'eval_wer': 45.24076147816349, 'eval_runtime': 1002.5262, 'eval_samples_per_second': 0.185, 'eval_steps_per_second': 0.024, 'epoch': 1.92}
# c:\Users\PcUser\anaconda3\Lib\site-packages\torch\utils\checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#   0%|          | 0/24 [00:00<?, ?it/s]
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}
# {'eval_loss': 0.4773434102535248, 'eval_wer': 42.66517357222844, 'eval_runtime': 998.6769, 'eval_samples_per_second': 0.185, 'eval_steps_per_second': 0.024, 'epoch': 2.02}
# c:\Users\PcUser\anaconda3\Lib\site-packages\torch\utils\checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#   0%|          | 0/24 [00:00<?, ?it/s]
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}
# {'eval_loss': 0.4911433160305023, 'eval_wer': 44.00895856662934, 'eval_runtime': 1001.1671, 'eval_samples_per_second': 0.185, 'eval_steps_per_second': 0.024, 'epoch': 2.12}
# c:\Users\PcUser\anaconda3\Lib\site-packages\torch\utils\checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# {'loss': 0.1931, 'grad_norm': 4.400010108947754, 'learning_rate': 7.500000000000001e-06, 'epoch': 2.16}
#   0%|          | 0/24 [00:00<?, ?it/s]
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}
# {'eval_loss': 0.49916088581085205, 'eval_wer': 43.89697648376259, 'eval_runtime': 1001.748, 'eval_samples_per_second': 0.185, 'eval_steps_per_second': 0.024, 'epoch': 2.21}
# c:\Users\PcUser\anaconda3\Lib\site-packages\torch\utils\checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#   0%|          | 0/24 [00:00<?, ?it/s]
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}
# {'eval_loss': 0.49781498312950134, 'eval_wer': 44.34490481522956, 'eval_runtime': 1001.0293, 'eval_samples_per_second': 0.185, 'eval_steps_per_second': 0.024, 'epoch': 2.31}
# c:\Users\PcUser\anaconda3\Lib\site-packages\torch\utils\checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# {'loss': 0.1579, 'grad_norm': 7.151217937469482, 'learning_rate': 7e-06, 'epoch': 2.4}
#   0%|          | 0/24 [00:00<?, ?it/s]
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}
# {'eval_loss': 0.4952438771724701, 'eval_wer': 44.23292273236282, 'eval_runtime': 1004.6995, 'eval_samples_per_second': 0.184, 'eval_steps_per_second': 0.024, 'epoch': 2.4}
# c:\Users\PcUser\anaconda3\Lib\site-packages\torch\utils\checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#   0%|          | 0/24 [00:00<?, ?it/s]
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}
# {'eval_loss': 0.4933006763458252, 'eval_wer': 43.56103023516237, 'eval_runtime': 1008.3751, 'eval_samples_per_second': 0.183, 'eval_steps_per_second': 0.024, 'epoch': 2.5}
# c:\Users\PcUser\anaconda3\Lib\site-packages\torch\utils\checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#   0%|          | 0/24 [00:00<?, ?it/s]
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}
# {'eval_loss': 0.48332372307777405, 'eval_wer': 43.89697648376259, 'eval_runtime': 1007.868, 'eval_samples_per_second': 0.184, 'eval_steps_per_second': 0.024, 'epoch': 2.6}
# c:\Users\PcUser\anaconda3\Lib\site-packages\torch\utils\checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# {'loss': 0.1615, 'grad_norm': 6.696218013763428, 'learning_rate': 6.5000000000000004e-06, 'epoch': 2.64}
#   0%|          | 0/24 [00:00<?, ?it/s]
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}
# {'eval_loss': 0.48508238792419434, 'eval_wer': 42.889137737961924, 'eval_runtime': 1000.7241, 'eval_samples_per_second': 0.185, 'eval_steps_per_second': 0.024, 'epoch': 2.69}
# c:\Users\PcUser\anaconda3\Lib\site-packages\torch\utils\checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#   0%|          | 0/24 [00:00<?, ?it/s]
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}
# {'eval_loss': 0.48852190375328064, 'eval_wer': 44.79283314669653, 'eval_runtime': 1002.4299, 'eval_samples_per_second': 0.185, 'eval_steps_per_second': 0.024, 'epoch': 2.79}
# c:\Users\PcUser\anaconda3\Lib\site-packages\torch\utils\checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# {'loss': 0.1606, 'grad_norm': 7.001290798187256, 'learning_rate': 6e-06, 'epoch': 2.88}
#   0%|          | 0/24 [00:00<?, ?it/s]
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}
# {'eval_loss': 0.4941169321537018, 'eval_wer': 45.464725643896976, 'eval_runtime': 1009.3552, 'eval_samples_per_second': 0.183, 'eval_steps_per_second': 0.024, 'epoch': 2.88}
# ...
# Non-default generation parameters: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}
# {'eval_loss': 0.5030043721199036, 'eval_wer': 41.65733482642777, 'eval_runtime': 1006.9233, 'eval_samples_per_second': 0.184, 'eval_steps_per_second': 0.024, 'epoch': 4.9}
# c:\Users\PcUser\anaconda3\Lib\site-packages\torch\utils\checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#   0%|          | 0/24 [00:00<?, ?it/s]
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}
# {'eval_loss': 0.5023366212844849, 'eval_wer': 40.6494960806271, 'eval_runtime': 1000.8813, 'eval_samples_per_second': 0.185, 'eval_steps_per_second': 0.024, 'epoch': 5.0}
# c:\Users\PcUser\anaconda3\Lib\site-packages\torch\utils\checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# {'loss': 0.0299, 'grad_norm': 0.7701663374900818, 'learning_rate': 1.5e-06, 'epoch': 5.05}
#   0%|          | 0/24 [00:00<?, ?it/s]
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}
# {'eval_loss': 0.5031846165657043, 'eval_wer': 40.76147816349384, 'eval_runtime': 993.787, 'eval_samples_per_second': 0.186, 'eval_steps_per_second': 0.024, 'epoch': 5.1}
# c:\Users\PcUser\anaconda3\Lib\site-packages\torch\utils\checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#   0%|          | 0/24 [00:00<?, ?it/s]
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}
# {'eval_loss': 0.5043706297874451, 'eval_wer': 40.6494960806271, 'eval_runtime': 1006.8296, 'eval_samples_per_second': 0.184, 'eval_steps_per_second': 0.024, 'epoch': 5.19}
# c:\Users\PcUser\anaconda3\Lib\site-packages\torch\utils\checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# {'loss': 0.0145, 'grad_norm': 1.0340811014175415, 'learning_rate': 1.0000000000000002e-06, 'epoch': 5.29}
#   0%|          | 0/24 [00:00<?, ?it/s]
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}
# {'eval_loss': 0.5051472783088684, 'eval_wer': 40.31354983202687, 'eval_runtime': 1000.2677, 'eval_samples_per_second': 0.185, 'eval_steps_per_second': 0.024, 'epoch': 5.29}
# c:\Users\PcUser\anaconda3\Lib\site-packages\torch\utils\checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#   0%|          | 0/24 [00:00<?, ?it/s]
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}
# {'eval_loss': 0.5070542693138123, 'eval_wer': 39.97760358342665, 'eval_runtime': 1001.0273, 'eval_samples_per_second': 0.185, 'eval_steps_per_second': 0.024, 'epoch': 5.38}
# c:\Users\PcUser\anaconda3\Lib\site-packages\torch\utils\checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#   0%|          | 0/24 [00:00<?, ?it/s]
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}
# {'eval_loss': 0.5082359313964844, 'eval_wer': 40.089585666293395, 'eval_runtime': 995.4675, 'eval_samples_per_second': 0.186, 'eval_steps_per_second': 0.024, 'epoch': 5.48}
# c:\Users\PcUser\anaconda3\Lib\site-packages\torch\utils\checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# {'loss': 0.0145, 'grad_norm': 1.2071610689163208, 'learning_rate': 5.000000000000001e-07, 'epoch': 5.53}
#   0%|          | 0/24 [00:00<?, ?it/s]
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}
# {'eval_loss': 0.5089965462684631, 'eval_wer': 40.31354983202687, 'eval_runtime': 1005.0209, 'eval_samples_per_second': 0.184, 'eval_steps_per_second': 0.024, 'epoch': 5.58}
# c:\Users\PcUser\anaconda3\Lib\site-packages\torch\utils\checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#   0%|          | 0/24 [00:00<?, ?it/s]
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}
# {'eval_loss': 0.508772611618042, 'eval_wer': 40.42553191489361, 'eval_runtime': 995.3988, 'eval_samples_per_second': 0.186, 'eval_steps_per_second': 0.024, 'epoch': 5.67}
# c:\Users\PcUser\anaconda3\Lib\site-packages\torch\utils\checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# {'loss': 0.0205, 'grad_norm': 0.7186576128005981, 'learning_rate': 0.0, 'epoch': 5.77}
#   0%|          | 0/24 [00:00<?, ?it/s]
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}
# {'eval_loss': 0.5087454915046692, 'eval_wer': 40.42553191489361, 'eval_runtime': 997.0036, 'eval_samples_per_second': 0.186, 'eval_steps_per_second': 0.024, 'epoch': 5.77}
# There were missing keys in the checkpoint model loaded: ['proj_out.weight'].
# {'train_runtime': 152738.8718, 'train_samples_per_second': 0.063, 'train_steps_per_second': 0.004, 'train_loss': 0.257595775226752, 'epoch': 5.77}
# TrainOutput(global_step=600, training_loss=0.257595775226752, metrics={'train_runtime': 152738.8718, 'train_samples_per_second': 0.063, 'train_steps_per_second': 0.004, 'total_flos': 2.7675339890688e+18, 'train_loss': 0.257595775226752, 'epoch': 5.769230769230769})

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
kwargs = {
    # "dataset_tags": "mozilla-foundation/common_voice_11_0",
    "dataset": "Whisper",  # a 'pretty' name for the training dataset
    "dataset_args": "config: ar, split: test",
    "language": "ar",
    "model_name": "Whisper Small Arabic",  # a 'pretty' name for your model
    "finetuned_from": "openai/whisper-small",
    "tasks": "automatic-speech-recognition",
}

# %%
trainer.push_to_hub(**kwargs)
# Out:
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}
# model.safetensors:   0%|          | 0.00/967M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/AyaOsta/lebanese_dialect_asr/commit/8ab3bcaa14ec0e9d01df548834a5593686e9b17d', commit_message='End of training', commit_description='', oid='8ab3bcaa14ec0e9d01df548834a5593686e9b17d', pr_url=None, pr_revision=None, pr_num=None)

# %%
tokenizer.push_to_hub("lebanese_dialect_asr")
# Out:
# README.md:   0%|          | 0.00/5.24k [00:00<?, ?B/s]
# c:\Users\PcUser\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:157: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\PcUser\.cache\huggingface\hub\models--AyaOsta--lebanese_dialect_asr. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# CommitInfo(commit_url='https://huggingface.co/AyaOsta/lebanese_dialect_asr/commit/5ff8487ea80e47d94b1d070d63c0b21e9339174f', commit_message='Upload tokenizer', commit_description='', oid='5ff8487ea80e47d94b1d070d63c0b21e9339174f', pr_url=None, pr_revision=None, pr_num=None)

# %%
from transformers import pipeline
import gradio as gr

pipe = pipeline(model="AyaOsta/lebanese_dialect_asr")  # change to "your-username/the-name-you-picked"

def transcribe(audio):
    text = pipe(audio)["text"]
    return text
# Out:
# config.json:   0%|          | 0.00/2.41k [00:00<?, ?B/s]
# c:\Users\PcUser\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:157: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\PcUser\.cache\huggingface\hub\models--AyaOsta--lebanese_dialect_asr. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# model.safetensors:   0%|          | 0.00/967M [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 from transformers import pipeline
#       2 import gradio as gr
# ----> 4 pipe = pipeline(model="AyaOsta/lebanese_dialect_asr")  # change to "your-username/the-name-you-picked"
#       6 def transcribe(audio):
#       7     text = pipe(audio)["text"]
#
# File c:\Users\PcUser\anaconda3\Lib\site-packages\transformers\pipelines\__init__.py:895, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, framework, revision, use_fast, token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     893 if isinstance(model, str) or framework is None:
#     894     model_classes = {"tf": targeted_task["tf"], "pt": targeted_task["pt"]}
# --> 895     framework, model = infer_framework_load_model(
#     896         model,
#     897         model_classes=model_classes,
#     898         config=config,
#     899         framework=framework,
#     900         task=task,
#     901         **hub_kwargs,
#     902         **model_kwargs,
#     903     )
#     905 model_config = model.config
#     906 hub_kwargs["_commit_hash"] = model.config._commit_hash
#
# File c:\Users\PcUser\anaconda3\Lib\site-packages\transformers\pipelines\base.py:283, in infer_framework_load_model(model, config, model_classes, task, framework, **model_kwargs)
#     277     logger.warning(
#     278         "Model might be a PyTorch model (ending with `.bin`) but PyTorch is not available. "
#     279         "Trying to load the model with Tensorflow."
#     280     )
#     282 try:
# --> 283     model = model_class.from_pretrained(model, **kwargs)
#     284     if hasattr(model, "eval"):
#     285         model = model.eval()
#
# File c:\Users\PcUser\anaconda3\Lib\site-packages\transformers\models\auto\auto_factory.py:564, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     562 elif type(config) in cls._model_mapping.keys():
#     563     model_class = _get_model_class(config, cls._model_mapping)
# --> 564     return model_class.from_pretrained(
#     565         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     566     )
#     567 raise ValueError(
#     568     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     569     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     570 )
#
# File c:\Users\PcUser\anaconda3\Lib\site-packages\transformers\modeling_utils.py:3428, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    3412 try:
#    3413     # Load from URL or cache if already cached
#    3414     cached_file_kwargs = {
#    3415         "cache_dir": cache_dir,
#    3416         "force_download": force_download,
#    (...)
#    3426         "_commit_hash": commit_hash,
#    3427     }
# -> 3428     resolved_archive_file = cached_file(pretrained_model_name_or_path, filename, **cached_file_kwargs)
#    3430     # Since we set _raise_exceptions_for_missing_entries=False, we don't get an exception but a None
#    3431     # result when internet is up, the repo and revision exist, but the file does not.
#    3432     if resolved_archive_file is None and filename == _add_variant(SAFE_WEIGHTS_NAME, variant):
#    3433         # Maybe the checkpoint is sharded, we try to grab the index name in this case.
#
# File c:\Users\PcUser\anaconda3\Lib\site-packages\transformers\utils\hub.py:402, in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     399 user_agent = http_user_agent(user_agent)
#     400 try:
#     401     # Load from URL or cache if already cached
# --> 402     resolved_file = hf_hub_download(
#     403         path_or_repo_id,
#     404         filename,
#     405         subfolder=None if len(subfolder) == 0 else subfolder,
#     406         repo_type=repo_type,
#     407         revision=revision,
#     408         cache_dir=cache_dir,
#     409         user_agent=user_agent,
#     410         force_download=force_download,
#     411         proxies=proxies,
#     412         resume_download=resume_download,
#     413         token=token,
#     414         local_files_only=local_files_only,
#     415     )
#     416 except GatedRepoError as e:
#     417     resolved_file = _get_cache_file_to_return(path_or_repo_id, full_filename, cache_dir, revision)
#
# File c:\Users\PcUser\anaconda3\Lib\site-packages\huggingface_hub\utils\_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File c:\Users\PcUser\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:1221, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, legacy_cache_layout, resume_download, force_filename, local_dir_use_symlinks)
#    1202     return _hf_hub_download_to_local_dir(
#    1203         # Destination
#    1204         local_dir=local_dir,
#    (...)
#    1218         local_files_only=local_files_only,
#    1219     )
#    1220 else:
# -> 1221     return _hf_hub_download_to_cache_dir(
#    1222         # Destination
#    1223         cache_dir=cache_dir,
#    1224         # File info
#    1225         repo_id=repo_id,
#    1226         filename=filename,
#    1227         repo_type=repo_type,
#    1228         revision=revision,
#    1229         # HTTP info
#    1230         headers=headers,
#    1231         proxies=proxies,
#    1232         etag_timeout=etag_timeout,
#    1233         endpoint=endpoint,
#    1234         # Additional options
#    1235         local_files_only=local_files_only,
#    1236         force_download=force_download,
#    1237     )
#
# File c:\Users\PcUser\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:1367, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, headers, proxies, etag_timeout, endpoint, local_files_only, force_download)
#    1365 Path(lock_path).parent.mkdir(parents=True, exist_ok=True)
#    1366 with WeakFileLock(lock_path):
# -> 1367     _download_to_tmp_and_move(
#    1368         incomplete_path=Path(blob_path + ".incomplete"),
#    1369         destination_path=Path(blob_path),
#    1370         url_to_download=url_to_download,
#    1371         proxies=proxies,
#    1372         headers=headers,
#    1373         expected_size=expected_size,
#    1374         filename=filename,
#    1375         force_download=force_download,
#    1376     )
#    1377     _create_symlink(blob_path, pointer_path, new_blob=True)
#    1379 return pointer_path
#
# File c:\Users\PcUser\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:1884, in _download_to_tmp_and_move(incomplete_path, destination_path, url_to_download, proxies, headers, expected_size, filename, force_download)
#    1881         _check_disk_space(expected_size, incomplete_path.parent)
#    1882         _check_disk_space(expected_size, destination_path.parent)
# -> 1884     http_get(
#    1885         url_to_download,
#    1886         f,
#    1887         proxies=proxies,
#    1888         resume_size=resume_size,
#    1889         headers=headers,
#    1890         expected_size=expected_size,
#    1891     )
#    1893 logger.info(f"Download complete. Moving file to {destination_path}")
#    1894 _chmod_and_move(incomplete_path, destination_path)
#
# File c:\Users\PcUser\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:539, in http_get(url, temp_file, proxies, resume_size, headers, expected_size, displayed_filename, _nb_retries, _tqdm_bar)
#     537 new_resume_size = resume_size
#     538 try:
# --> 539     for chunk in r.iter_content(chunk_size=DOWNLOAD_CHUNK_SIZE):
#     540         if chunk:  # filter out keep-alive new chunks
#     541             progress.update(len(chunk))
#
# File c:\Users\PcUser\anaconda3\Lib\site-packages\requests\models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File c:\Users\PcUser\anaconda3\Lib\site-packages\urllib3\response.py:936, in HTTPResponse.stream(self, amt, decode_content)
#     934 else:
#     935     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# --> 936         data = self.read(amt=amt, decode_content=decode_content)
#     938         if data:
#     939             yield data
#
# File c:\Users\PcUser\anaconda3\Lib\site-packages\urllib3\response.py:879, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     876     if len(self._decoded_buffer) >= amt:
#     877         return self._decoded_buffer.get(amt)
# --> 879 data = self._raw_read(amt)
#     881 flush_decoder = amt is None or (amt != 0 and not data)
#     883 if not data and len(self._decoded_buffer) == 0:
#
# File c:\Users\PcUser\anaconda3\Lib\site-packages\urllib3\response.py:814, in HTTPResponse._raw_read(self, amt)
#     811 fp_closed = getattr(self._fp, "closed", False)
#     813 with self._error_catcher():
# --> 814     data = self._fp_read(amt) if not fp_closed else b""
#     815     if amt is not None and amt != 0 and not data:
#     816         # Platform-specific: Buggy versions of Python.
#     817         # Close the connection when no data is returned
#    (...)
#     822         # not properly close the connection in all cases. There is
#     823         # no harm in redundantly calling close.
#     824         self._fp.close()
#
# File c:\Users\PcUser\anaconda3\Lib\site-packages\urllib3\response.py:799, in HTTPResponse._fp_read(self, amt)
#     796     return buffer.getvalue()
#     797 else:
#     798     # StringIO doesn't like amt=None
# --> 799     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File c:\Users\PcUser\anaconda3\Lib\http\client.py:473, in HTTPResponse.read(self, amt)
#     470 if self.length is not None and amt > self.length:
#     471     # clip the read to the "end of response"
#     472     amt = self.length
# --> 473 s = self.fp.read(amt)
#     474 if not s and amt:
#     475     # Ideally, we would raise IncompleteRead if the content-length
#     476     # wasn't satisfied, but it might break compatibility.
#     477     self._close_conn()
#
# File c:\Users\PcUser\anaconda3\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File c:\Users\PcUser\anaconda3\Lib\ssl.py:1314, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1310     if flags != 0:
#    1311         raise ValueError(
#    1312           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313           self.__class__)
# -> 1314     return self.read(nbytes, buffer)
#    1315 else:
#    1316     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\PcUser\anaconda3\Lib\ssl.py:1166, in SSLSocket.read(self, len, buffer)
#    1164 try:
#    1165     if buffer is not None:
# -> 1166         return self._sslobj.read(len, buffer)
#    1167     else:
#    1168         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
iface = gr.Interface(
    fn=transcribe, 
    inputs=gr.Audio(type="filepath"), 
    outputs="text",
    title="Lebanese Speech Recognition Model",
    description="Realtime demo for Arabic speech recognition using a fine-tuned Whisper small model.",
)

iface.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7861
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# c:\Users\PcUser\anaconda3\Lib\site-packages\transformers\models\whisper\generation_whisper.py:480: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
